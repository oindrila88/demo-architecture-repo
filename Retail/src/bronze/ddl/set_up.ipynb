-- %%
CREATE CATALOG IF NOT EXISTS retail_oc

-- %%
-- Schema for PostgreSQL Source
CREATE SCHEMA IF NOT EXISTS retail_oc.postgres_bronze;

-- Schema for Salesforce Source
CREATE SCHEMA IF NOT EXISTS retail_oc.salesforce_bronze;

-- Schema for Blob Source
CREATE SCHEMA IF NOT EXISTS retail_oc.blob_bronze
